# %%
import awswrangler as wr
import boto3
from dynaconf import Dynaconf

config = Dynaconf(settings_files=['settings.toml'], load_dotenv=False)

S3_BUCKET_NAME_X = config.S3_BUCKET_NAME_X

# %%
my_session = boto3.Session(region_name="us-east-1")
wr.s3.does_object_exist(S3_BUCKET_NAME_X, boto3_session=my_session)
# Out:
# True

# %%
wr.s3.read_parquet(S3_BUCKET_NAME_X)
# Out:
#       CentralAir_Y  Street_Pave  Utilities_AllPub  YrSold  YearBuilt_YrSold  \
# Id
# 893              1            1                 1    2006              43.0
# 1106             1            1                 1    2010              16.0
# 414              1            1                 1    2010              83.0
# 523              1            1                 1    2006              59.0
# 1037             1            1                 1    2009               2.0
# ...            ...          ...               ...     ...               ...
# 1096             1            1                 1    2007               1.0
# 1131             1            1                 1    2009              81.0
# 1295             1            1                 1    2006              51.0
# 861              1            1                 1    2007              89.0
# 1127             1            1                 1    2009               2.0
#
# ...
